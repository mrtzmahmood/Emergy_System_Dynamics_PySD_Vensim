# %%
# %matplotlib inline
import ipywidgets as widgets
from IPython.display import Image
import pysd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Image(filename='emergy.png')

# %%
model = pysd.read_vensim('emergy.mdl')
res = model.run()

# %%
res['firms population'].plot()
# Out:
# <AxesSubplot:>

# %%
res['consume per capita'].plot()
# Out:
# <AxesSubplot:>
